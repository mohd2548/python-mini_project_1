# %%
from googletrans import Translator
translator = Translator()

user = input("Paste Here :...............")
translated = translator.translate(user,src = 'en', dest = 'hi')
print(translated.text)
# Out:
# Paste Here :............... 	 Nuptse is a mountain in the Khumbu region of the Mahalangur Himal, a part of the Nepalese Himalayas. It lies 2 kilometres (1.2 mi) to the southwest of Mount Everest. The main peak, Nuptse I, with an elevation of 7,861 metres (25,791 ft), was first climbed in 1961 by Dennis Davis and Sherpa Tashi. This photograph shows Nuptse from the west, as viewed from Kala Patthar.
# नुप्त्से, नेपाली हिमालय के एक भाग, महालंगुर हिमाल के खुम्बू क्षेत्र में एक पर्वत है।यह माउंट एवरेस्ट के दक्षिण-पश्चिम में 2 किलोमीटर (1.2 मील) दूर स्थित है।7,861 मीटर (25,791 फीट) की ऊंचाई वाली मुख्य चोटी, नुप्त्से I, पहली बार 1961 में डेनिस डेविस और शेरपा ताशी द्वारा चढ़ाई गई थी।यह तस्वीर पश्चिम से नुप्त्से को दिखाती है, जैसा कि काला पत्थर से देखा गया है।

# %%
# pip install googletrans==4.0.0-rc1
